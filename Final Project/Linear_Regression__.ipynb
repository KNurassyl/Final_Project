# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/magzhan_abish/Downloads/wfp_food_prices_kaz.csv')

# %%
data = data.iloc[1: , :]

# %%
data['commodity'].unique()
# Out:
# array(['Potatoes', 'Wheat flour (first grade)', 'Meat (beef)', 'Milk',
#        'Oil (sunflower)'], dtype=object)

# %%
data['market'].unique()
# Out:
# array(['Nur-Sultan', 'Almaty', 'Kostanay', 'Aktau'], dtype=object)

# %%
category1 = data[data['commodity']=="Potatoes"]

# %%
category1
# Out:
#             date            admin1            admin2      market latitude  \
# 1     2005-11-15      Akmolinskaya       Tselinograd  Nur-Sultan    51.17
# 6     2005-11-15  Almaty City area  Almaty City area      Almaty    43.28
# 11    2005-11-15     Kustanayskaya          Qostanay    Kostanay     53.2
# 16    2005-11-15    Mangistauskaya   Aqtau City area       Aktau    43.65
# 20    2005-12-15      Akmolinskaya       Tselinograd  Nur-Sultan    51.17
# ...          ...               ...               ...         ...      ...
# 3344  2020-10-15    Mangistauskaya   Aqtau City area       Aktau    43.65
# 3348  2020-11-15      Akmolinskaya       Tselinograd  Nur-Sultan    51.17
# 3352  2020-11-15  Almaty City area  Almaty City area      Almaty    43.28
# 3357  2020-11-15     Kustanayskaya          Qostanay    Kostanay     53.2
# 3362  2020-11-15    Mangistauskaya   Aqtau City area       Aktau    43.65
#
#      longitude            category commodity unit priceflag pricetype  \
# ...

# %%
category1['date']
# Out:
# 1       2005-11-15
# 6       2005-11-15
# 11      2005-11-15
# 16      2005-11-15
# 20      2005-12-15
#            ...
# 3344    2020-10-15
# 3348    2020-11-15
# 3352    2020-11-15
# 3357    2020-11-15
# 3362    2020-11-15
# Name: date, Length: 724, dtype: object

# %%
category1['date'].unique()
# Out:
# array(['2005-11-15', '2005-12-15', '2006-01-15', '2006-02-15',
#        '2006-03-15', '2006-04-15', '2006-05-15', '2006-06-15',
#        '2006-07-15', '2006-08-15', '2006-09-15', '2006-10-15',
#        '2006-11-15', '2006-12-15', '2007-01-15', '2007-02-15',
#        '2007-03-15', '2007-04-15', '2007-05-15', '2007-06-15',
#        '2007-07-15', '2007-08-15', '2007-09-15', '2007-10-15',
#        '2007-11-15', '2007-12-15', '2008-01-15', '2008-02-15',
#        '2008-03-15', '2008-04-15', '2008-05-15', '2008-06-15',
#        '2008-07-15', '2008-08-15', '2008-09-15', '2008-10-15',
#        '2008-11-15', '2008-12-15', '2009-01-15', '2009-02-15',
#        '2009-03-15', '2009-04-15', '2009-05-15', '2009-06-15',
#        '2009-07-15', '2009-08-15', '2009-09-15', '2009-10-15',
#        '2009-11-15', '2009-12-15', '2010-01-15', '2010-02-15',
#        '2010-03-15', '2010-04-15', '2010-05-15', '2010-06-15',
#        '2010-07-15', '2010-08-15', '2010-09-15', '2010-10-15',
# ...

# %%
import datetime as dt
pd.options.mode.chained_assignment = None
category1['date'] = pd.to_datetime(category1['date'])
category1['date']= category1['date'].map(dt.datetime.toordinal)

# %%
category1['date']
# Out:
# 1       732265
# 6       732265
# 11      732265
# 16      732265
# 20      732295
#          ...
# 3344    737713
# 3348    737744
# 3352    737744
# 3357    737744
# 3362    737744
# Name: date, Length: 724, dtype: int64

# %%
category1['date'].unique()
# Out:
# array([732265, 732295, 732326, 732357, 732385, 732416, 732446, 732477,
#        732507, 732538, 732569, 732599, 732630, 732660, 732691, 732722,
#        732750, 732781, 732811, 732842, 732872, 732903, 732934, 732964,
#        732995, 733025, 733056, 733087, 733116, 733147, 733177, 733208,
#        733238, 733269, 733300, 733330, 733361, 733391, 733422, 733453,
#        733481, 733512, 733542, 733573, 733603, 733634, 733665, 733695,
#        733726, 733756, 733787, 733818, 733846, 733877, 733907, 733938,
#        733968, 733999, 734030, 734060, 734091, 734121, 734152, 734183,
#        734211, 734242, 734272, 734303, 734333, 734364, 734395, 734425,
#        734456, 734486, 734517, 734548, 734577, 734608, 734638, 734669,
#        734699, 734730, 734761, 734791, 734822, 734852, 734883, 734914,
#        734942, 734973, 735003, 735034, 735064, 735095, 735126, 735156,
#        735187, 735217, 735248, 735279, 735307, 735338, 735368, 735399,
# ...

# %%
category1_data = pd.DataFrame().assign(Date=category1['date'], Price=category1['price'])

# %%
category1_data
# Out:
#         Date  Price
# 1     732265   40.0
# 6     732265   49.0
# 11    732265   34.0
# 16    732265   55.0
# 20    732295   42.0
# ...      ...    ...
# 3344  737713  152.0
# 3348  737744  124.0
# 3352  737744  110.0
# 3357  737744  104.0
# 3362  737744  147.0
#
# [724 rows x 2 columns]

# %%
sns.set(rc={'figure.figsize':(20,20)})
category1_data["Price"] = pd.to_numeric(category1_data["Price"])
sns.scatterplot(x = category1_data["Date"], y = category1_data["Price"])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Price'>

# %%
sns.regplot(x = category1_data["Date"], y = category1_data["Price"],scatter_kws={"color": "blue"}, line_kws={"color": "red"})
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Price'>

# %%
category2 = data[data['commodity']=="Meat (beef)"]

# %%
category2['date'] = pd.to_datetime(category2['date'])
category2['date']= category2['date'].map(dt.datetime.toordinal)

# %%
category2_data = pd.DataFrame().assign(Date=category2['date'], Price=category2['price'])

# %%
sns.set(rc={'figure.figsize':(20,20)})
category2_data["Price"] = pd.to_numeric(category2_data["Price"])
sns.scatterplot(x = category2_data["Date"], y = category2_data["Price"])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Price'>

# %%
sns.regplot(x = category2_data["Date"], y = category2_data["Price"],scatter_kws={"color": "blue"}, line_kws={"color": "red"})
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Price'>

# %%
category3 = data[data['commodity']=="Wheat flour (first grade)"]

# %%
category3_almaty = category3[category3['market'] == "Almaty"]

# %%
category3_almaty
# Out:
#             date            admin1            admin2  market latitude  \
# 7     2005-11-15  Almaty City area  Almaty City area  Almaty    43.28
# 26    2005-12-15  Almaty City area  Almaty City area  Almaty    43.28
# 45    2006-01-15  Almaty City area  Almaty City area  Almaty    43.28
# 64    2006-02-15  Almaty City area  Almaty City area  Almaty    43.28
# 83    2006-03-15  Almaty City area  Almaty City area  Almaty    43.28
# ...          ...               ...               ...     ...      ...
# 3281  2020-07-15  Almaty City area  Almaty City area  Almaty    43.28
# 3299  2020-08-15  Almaty City area  Almaty City area  Almaty    43.28
# 3317  2020-09-15  Almaty City area  Almaty City area  Almaty    43.28
# 3335  2020-10-15  Almaty City area  Almaty City area  Almaty    43.28
# 3353  2020-11-15  Almaty City area  Almaty City area  Almaty    43.28
#
#      longitude            category                  commodity unit priceflag  \
# ...

# %%
category3_almaty['date'] = pd.to_datetime(category3_almaty['date'])
category3_almaty['date']= category3_almaty['date'].map(dt.datetime.toordinal)

# %%
category3_almaty_data = pd.DataFrame().assign(Date=category3_almaty['date'], Price=category3_almaty['price'])

# %%
category3_almaty_data
# Out:
#         Date  Price
# 7     732265   53.0
# 26    732295   53.0
# 45    732326   54.0
# 64    732357   54.0
# 83    732385   54.0
# ...      ...    ...
# 3281  737621  220.0
# 3299  737652  224.0
# 3317  737683  224.0
# 3335  737713  237.0
# 3353  737744  242.0
#
# [181 rows x 2 columns]

# %%
sns.set(rc={'figure.figsize':(20,20)})
category3_almaty_data["Price"] = pd.to_numeric(category3_almaty_data["Price"])
sns.scatterplot(x = category3_almaty_data["Date"], y = category3_almaty_data["Price"])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Price'>

# %%
sns.regplot(x = category3_almaty_data["Date"], y = category3_almaty_data["Price"],scatter_kws={"color": "blue"}, line_kws={"color": "red"}).set(title='Almaty')
# Out:
# [Text(0.5, 1.0, 'Almaty')]

# %%
category3_astana = category3[category3['market'] == "Nur-Sultan"]

category3_astana['date'] = pd.to_datetime(category3_astana['date'])
category3_astana['date']= category3_astana['date'].map(dt.datetime.toordinal)

category3_astana_data = pd.DataFrame().assign(Date=category3_astana['date'], Price=category3_astana['price'])

# %%
category3_kostanay = category3[category3['market'] == "Kostanay"]

category3_kostanay['date'] = pd.to_datetime(category3_kostanay['date'])
category3_kostanay['date']= category3_kostanay['date'].map(dt.datetime.toordinal)

category3_kostanay_data = pd.DataFrame().assign(Date=category3_kostanay['date'], Price=category3_kostanay['price'])

# %%
category3_aktau = category3[category3['market'] == "Aktau"]

category3_aktau['date'] = pd.to_datetime(category3_aktau['date'])
category3_aktau['date']= category3_aktau['date'].map(dt.datetime.toordinal)

category3_aktau_data = pd.DataFrame().assign(Date=category3_aktau['date'], Price=category3_aktau['price'])

# %%
category3_astana_data['Price'] = pd.to_numeric(category3_astana_data['Price'])
category3_kostanay_data['Price'] = pd.to_numeric(category3_kostanay_data['Price'])
category3_aktau_data['Price'] = pd.to_numeric(category3_aktau_data['Price'])

# %%
figure, axis = plt.subplots(2,2)

axis[0,0].plot(category3_almaty_data["Date"],category3_almaty_data["Price"])
axis[0,0].set_title('Almaty')
axis[0,1].plot(category3_astana_data["Date"],category3_astana_data["Price"])
axis[0,1].set_title('Astana')
axis[1,0].plot(category3_kostanay_data["Date"],category3_kostanay_data["Price"])
axis[1,0].set_title('Kostanay')
axis[1,1].plot(category3_aktau_data["Date"],category3_aktau_data["Price"])
axis[1,1].set_title('Aktau')
# Out:
# Text(0.5, 1.0, 'Aktau')

# %%
sns.regplot(x = category3_astana_data["Date"], y = category3_astana_data["Price"],scatter_kws={"color": "blue"}, line_kws={"color": "red"}).set(title='Astana')
# Out:
# [Text(0.5, 1.0, 'Astana')]

# %%
sns.regplot(x = category3_kostanay_data["Date"], y = category3_kostanay_data["Price"],scatter_kws={"color": "blue"}, line_kws={"color": "red"}).set(title='Kostanay')
# Out:
# [Text(0.5, 1.0, 'Kostanay')]

# %%
sns.regplot(x = category3_aktau_data["Date"], y = category3_aktau_data["Price"],scatter_kws={"color": "blue"}, line_kws={"color": "red"}).set(title='Aktau')
# Out:
# [Text(0.5, 1.0, 'Aktau')]

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
 
X = category2_data.drop(['Price'], axis=1)
Y = category2_data['Price']

X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, train_size=0.8, test_size=0.2, random_state=0)

# %%
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.linear_model import LinearRegression
 
model_LR = LinearRegression()
model_LR.fit(X_train, Y_train)
Y_pred = model_LR.predict(X_valid)
 
print(mean_absolute_percentage_error(Y_valid, Y_pred))
# Out:
# 0.11428229426974129

# %%
print(model_LR.coef_)
# Out:
# [0.26403365]

# %%
print(model_LR.intercept_)
# Out:
# -192933.51545354433
